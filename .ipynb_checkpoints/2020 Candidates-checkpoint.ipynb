# %%
# %%time

import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime

PRES_CMTES = ['BENNET FOR AMERICA','BIDEN FOR PRESIDENT','BULLOCK FOR PRESIDENT','PETE FOR AMERICA, INC.','KAMALA HARRIS FOR THE PEOPLE','AMY KLOBUCHAR VICTORY COMMITTEE','WAYNE MESSAM FOR AMERICA, INC.','TIM RYAN FOR AMERICA','WARREN FOR PRESIDENT, INC.','MARIANNE WILLIAMSON FOR PRESIDENT','FRIENDS OF ANDREW YANG','CORY 2020','JULIAN FOR THE FUTURE','FRIENDS OF JOHN DELANEY','TULSI NOW','BETO FOR AMERICA','BERNIE 2020','JOE SESTAK FOR PRESIDENT','TOM STEYER 2020']
CORE_COLUMNS = ['CMTE_NM','RPT_TP','NAME','CITY','STATE','ZIP_CODE','TRANSACTION_DT','TRANSACTION_AMT','PURPOSE','CATEGORY']


# Read in data
df_header = pd.read_csv("~/Documents/Insight/Data - Insight/oppexp_header_file.csv")
df = pd.read_csv("~/Documents/Insight/Data - Insight/oppexp20/oppexp.txt", delimiter="|", low_memory=False, names=df_header.columns, index_col=False)
cmte_header = pd.read_csv("~/Documents/Insight/Data - Insight/cm20/cm_header_file.csv") # pull in header for committee names file
cmte_names = pd.read_csv("~/Documents/Insight/Data - Insight/cm20/cm.txt", delimiter="|", names=cmte_header.columns) # pull in committee names file

# Clean data
df = ( df.set_index('CMTE_ID') ).join(cmte_names.set_index('CMTE_ID')) 
df = df.reset_index()
df['TRANSACTION_DT']=pd.to_datetime(df['TRANSACTION_DT'],errors = 'coerce')
df = df[df['TRANSACTION_AMT']>0]

print('timed')
# Out:
# timed
# Wall time: 9.71 s

# %%
candidates = ['trump','cruz','kasich','rubio','carson','bush','paul','christie','huckabee','fiorina','gilmore','santorum','perry','walker','jindal','graham','pataki']
cmte_names = df.CMTE_NM.unique()
    
for candidate in candidates:
    for name in cmte_names:
        if candidate.upper() in str(name):
            print(name)

# %%
candidates = ['bennet','biden','booker','bullock','buttigieg','pete','castro','delaney','gabbard','harris','klobuchar','messam','rourke','ryan','sanders','sestak','steyer','warren','williamson','yang','president','for america','2020','julian for the future']
cmte_names = df.CMTE_NM.unique()
    
for candidate in candidates:
    for name in cmte_names:
        if candidate.upper() in str(name):
            print(name)
# Out:
# BENNET FOR COLORADO
# BENNET FOR AMERICA
# BIDEN FOR PRESIDENT
# CORY BOOKER FOR SENATE
# BOOKER SENATE VICTORY
# BEN BULLOCK FOR CONGRESS INC.
# BULLOCK FOR PRESIDENT
# PETERSON FOR CONGRESS
# PETE KING FOR CONGRESS COMMITTEE
# PETE SESSIONS FOR CONGRESS
# PEOPLE FOR ENTERPRISE TRADE AND ECONOMIC GROWTH (PETE PAC)
# PETERS FOR MICHIGAN
# SCOTT PETERS FOR CONGRESS
# PETE AGUILAR FOR CONGRESS
# PETERS VICTORY FUND
# THE PETER NORBECK LEADERSHIP PAC
# PETER JOFFRION FOR CONGRESS
# AUSTIN PETERSEN FOR US SENATE
# PETE STAUBER FOR CONGRESS
# PETE FOR IOWA
# PETERS FOR CONGRESS
# LEA MARQUEZ PETERSON FOR CONGRESS
# PETER DE NEUFVILLE FOR CONGRESS, INC.
# ELIOT RABIN-PETER ELIOT FOR CONGRESS
# PETERS VICTORY 2020
# PETE FOR AMERICA, INC.
# COMMITTEE TO ELECT SAM PETERS
# COMMITTEE TO ELECT PETER KHALIL
# CASTRO FOR CONGRESS
# MARK CONGRESS 2020
# 2020 SENATE IMPACT
# GLEIB 2020
# PATRIOT DAY 1 2020
# SCHIFF HOLD THE HOUSE 2020
# DE BLASIO 2020
# BURDICK FOR CONGRESS 2020
# HOWIE HAWKINS 2020
# KEN ARMSTRONG FOR PRESIDENT 2020
# GODSTON 2020
# 2020 DEMOCRATIC NATIONAL CONVENTION COMMITTEE
# JULIAN FOR THE FUTURE

# %%
pres_cmtes = ['BENNET FOR AMERICA','BIDEN FOR PRESIDENT','BULLOCK FOR PRESIDENT','PETE FOR AMERICA, INC.','KAMALA HARRIS FOR THE PEOPLE','AMY KLOBUCHAR VICTORY COMMITTEE','WAYNE MESSAM FOR AMERICA, INC.','TIM RYAN FOR AMERICA','WARREN FOR PRESIDENT, INC.','MARIANNE WILLIAMSON FOR PRESIDENT','FRIENDS OF ANDREW YANG','CORY 2020','JULIAN FOR THE FUTURE','FRIENDS OF JOHN DELANEY','TULSI NOW','BETO FOR AMERICA','BERNIE 2020','JOE SESTAK FOR PRESIDENT','TOM STEYER 2020']
pres_cmtes
# Out:
# ['BENNET FOR AMERICA',
#  'BIDEN FOR PRESIDENT',
#  'BULLOCK FOR PRESIDENT',
#  'PETE FOR AMERICA, INC.',
#  'KAMALA HARRIS FOR THE PEOPLE',
#  'AMY KLOBUCHAR VICTORY COMMITTEE',
#  'WAYNE MESSAM FOR AMERICA, INC.',
#  'TIM RYAN FOR AMERICA',
#  'WARREN FOR PRESIDENT, INC.',
#  'MARIANNE WILLIAMSON FOR PRESIDENT',
#  'FRIENDS OF ANDREW YANG',
#  'CORY 2020',
#  'JULIAN FOR THE FUTURE',
#  'FRIENDS OF JOHN DELANEY',
#  'TULSI NOW',
#  'BETO FOR AMERICA',
#  'BERNIE 2020',
#  'JOE SESTAK FOR PRESIDENT',
#  'TOM STEYER 2020']

# %%
# %%time

from sklearn.cluster import DBSCAN
import numpy as np

clustering = DBSCAN(eps=30, min_samples=100).fit_predict(df[['TRANSACTION_AMT']])
#clustering.labels_

print(clustering)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Anaconda3\envs\insight\lib\site-packages\sklearn\cluster\dbscan_.py in fit_predict(self, X, y, sample_weight)
#     381             cluster labels
#     382         """
# --> 383         self.fit(X, sample_weight=sample_weight)
#     384         return self.labels_
#
# ~\Anaconda3\envs\insight\lib\site-packages\sklearn\cluster\dbscan_.py in fit(self, X, y, sample_weight)
#     349         X = check_array(X, accept_sparse='csr')
#     350         clust = dbscan(X, sample_weight=sample_weight,
# --> 351                        **self.get_params())
#     352         self.core_sample_indices_, self.labels_ = clust
#     353         if len(self.core_sample_indices_):
#
# ~\Anaconda3\envs\insight\lib\site-packages\sklearn\cluster\dbscan_.py in dbscan(X, eps, min_samples, metric, metric_params, algorithm, leaf_size, p, sample_weight, n_jobs)
#     173         # This has worst case O(n^2) memory complexity
#     174         neighborhoods = neighbors_model.radius_neighbors(X, eps,
# --> 175                                                          return_distance=False)
#     176
#     177     if sample_weight is None:
#
# ~\Anaconda3\envs\insight\lib\site-packages\sklearn\neighbors\base.py in radius_neighbors(self, X, radius, return_distance)
#     745             results = Parallel(n_jobs, **parallel_kwargs)(
#     746                 delayed_query(self._tree, X[s], radius, return_distance)
# --> 747                 for s in gen_even_slices(X.shape[0], n_jobs)
#     748             )
#     749             if return_distance:
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\envs\insight\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\envs\insight\lib\site-packages\sklearn\neighbors\base.py in _tree_query_radius_parallel_helper(tree, data, radius, return_distance)
#     578     cloudpickle under PyPy.
#     579     """
# --> 580     return tree.query_radius(data, radius, return_distance)
#     581
#     582
#
# sklearn\neighbors\binary_tree.pxi in sklearn.neighbors.kd_tree.BinaryTree.query_radius()
#
# sklearn\neighbors\binary_tree.pxi in sklearn.neighbors.kd_tree.BinaryTree.query_radius()
#
# MemoryError:
