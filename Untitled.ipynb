# %%
import pandas as pd
outliers = pd.read_csv("outliers2020.csv", index_col=0)

# %%
outliers.loc[outliers['CMTE_NM']=='CORY 2020']
# Out:
#           CMTE_ID AMNDT_IND  RPT_YR RPT_TP           IMAGE_NUM  LINE_NUM  \
# 327486  C00695510         A    2019     Q2  201909039163139113        23
# 327812  C00695510         A    2019     Q2  201909039163138278        23
# 328358  C00695510         A    2019     Q2  201909039163138317        23
# 327369  C00695510         A    2019     Q2  201909039163138813        23
# 327849  C00695510         A    2019     Q2  201909039163138918        23
# ...           ...       ...     ...    ...                 ...       ...
# 329346  C00695510         A    2019     Q1  201909039163130239        23
# 329214  C00695510         A    2019     Q1  201909039163130162        23
# 329604  C00695510         A    2019     Q1  201909039163130215        23
# 329453  C00695510         A    2019     Q1  201909039163130152        23
# 329562  C00695510         A    2019     Q1  201909039163130219        23
#
#        FORM_TP_CD SCHED_TP_CD                          NAME          CITY  \
# ...
